# %% [markdown]
# **Usage Scenarios**
#
# 1.  $10,000 Galley Kitchen Refresh in a 1960s Condo
# 2.  Renter-friendly makeover under $800
# 3.  Accessible Bathroom Remodel for Aging in Place
# 4. Small Patio Transformation for Entertaining
# 5. “Snap → Plan → Hire” (Kitchen Refresh)
# 6.  “Diagnose → Compare → Optimize” (Bathroom Remodel with Moisture Issue)
